# %%
from clean_and_analyze import analyze_data

YEARS = ["2016", "2017", "2018", "2019", "2020"]
TO_CLEAN_DATA_DIR = "data/clean_data/"
FROM_RAW_DATA_DIR = "data/raw_data/"

a, b, c, d = analyze_data.clean_and_analyze_all(YEARS, FROM_RAW_DATA_DIR, TO_CLEAN_DATA_DIR)
# Out:
# /home/foosuonchuang/capp30122/30122-project-cappy-funding/clean_and_analyze/clean_census.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poverty_df['State'] = poverty_df['State'].str.strip()
# /home/foosuonchuang/capp30122/30122-project-cappy-funding/clean_and_analyze/clean_census.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pop_df['State'] = pop_df['State'].str.strip()
# ...

# %%
d
# Out:
#          Year  Total Funding Received  \
# State
# Alabama  2016              11684439.0
# Alabama  2017              12104077.0
# Alabama  2018              15665904.0
# Alabama  2019              12503066.0
# Alabama  2020              12180702.0
# ...       ...                     ...
# Wyoming  2016                149557.0
# Wyoming  2017                133557.0
# Wyoming  2018                156715.0
# Wyoming  2019                171689.0
# Wyoming  2020                158891.0
#
#          Agriculture, Forestry, Fishing and Hunting  \
# State
# Alabama                                    0.347488
# Alabama                                    0.568783
# Alabama                                    0.429977
# Alabama                                    0.546280
# Alabama                                    0.236026
# ...                                             ...
# Wyoming                                    0.734603
# Wyoming                                    0.382007
# ...
